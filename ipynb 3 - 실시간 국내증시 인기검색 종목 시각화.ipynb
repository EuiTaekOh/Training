# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'

from tqdm import tqdm   # pip install tqdm
from libs import stock_daum, stock_naver

# %% [markdown]
# ## 실시간 국내증시 인기검색 종목 크롤링

# %%
df = stock_naver.get_실시간_국내증시_인기검색종목()
print(df.shape)
df
# Out:
# (10, 4)
#           direction                                                url  \
# 종목명
# 삼성전자             dn  https://finance.naver.com/item/main.nhn?code=0...
# HMM              up  https://finance.naver.com/item/main.nhn?code=0...
# 카카오              dn  https://finance.naver.com/item/main.nhn?code=0...
# 종근당바이오           up  https://finance.naver.com/item/main.nhn?code=0...
# SK바이오사이언스        up  https://finance.naver.com/item/main.nhn?code=3...
# LG화학             dn  https://finance.naver.com/item/main.nhn?code=0...
# 셀트리온             dn  https://finance.naver.com/item/main.nhn?code=0...
# SK이노베이션          dn  https://finance.naver.com/item/main.nhn?code=0...
# 현대차              up  https://finance.naver.com/item/main.nhn?code=0...
# SK하이닉스           dn  https://finance.naver.com/item/main.nhn?code=0...
#
#               거래가    종목코드
# 종목명
# 삼성전자        82100  005930
# HMM         39300  011200
# 카카오        119500  035720
# 종근당바이오      77400  063160
# SK바이오사이언스  163500  302440
# LG화학       890000  051910
# 셀트리온       270000  068270
# SK이노베이션    270000  096770
# 현대차        221500  005380
# SK하이닉스     130000  000660

# %% [markdown]
# ## 시각화

# %%
df['거래가'].plot(kind='bar', figsize=(10, 6))

# %%
ax = df['거래가'].plot(kind='bar', figsize=(14, 6), rot=0)

for p in ax.patches:
    box = p.get_bbox()  # matplotlib.transforms.Bbox 타입 (x0, y0, x1, y1 속성)
    
    x = box.xmin
    y = box.ymax
    text = "{:,}".format(int(box.ymax))
    
    # https://matplotlib.org/users/annotations.html
    ax.text(x, y, text, bbox={'boxstyle': 'round', 'fc': '#ffffff99'})
