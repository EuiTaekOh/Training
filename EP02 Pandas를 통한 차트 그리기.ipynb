# %%
# %matplotlib inline 
from matplotlib import pyplot as plt

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'

import pandas as pd

# %%
##line 타입

# %%
line1_df = pd.read_excel("data/sample-line-1.xlsx", index_col = "날짜")
print(line1_df.shape)
line1_df.head()
# Out:
# (3189, 5)
#                체결가   전일비     등락률  거래량(천주)  거래대금(백만)
# 날짜
# 2018-11-23  266.33  1.43  -0.53%    58346   2670694
# 2018-11-22  267.76  0.51  -0.19%    63147   2917863
# 2018-11-21  268.27  1.31  -0.49%    79375   3726326
# 2018-11-20  269.58  2.73  -1.00%    79088   3667388
# 2018-11-19  272.31  0.66  +0.24%    73094   3401282

# %%
line1_df['체결가'].plot(kind='line')

# %%
line2_df = pd.read_excel("data/sample-line-2.xlsx", index_col = "날짜")
print(line2_df.shape)
line2_df.head()
# Out:
# (100, 3)
#              삼성전자   LG전자   현대자동차
# 날짜
# 2018-11-23  42400  69400   93700
# 2018-11-22  42450  69200   92800
# 2018-11-21  42100  69700   97800
# 2018-11-20  42800  70500   97500
# 2018-11-19  43650  71600  101500

# %%
line2_df.plot()

# %%
pie_df = pd.read_excel('data/sample-pie.xlsx',index_col = '가수')
print(pie_df.shape)
pie_df.iloc[:10].plot(kind='pie' , y='곡수', legend=False, figsize=(5,5))
# Out:
# (48, 1)

# %%
bar_df = pd.read_excel('data/sample-bar.xlsx',index_col = '가수')
print(bar_df.shape)
bar_df.head()
# Out:
# (10, 1)
#                   0
# 가수
# Wanna One (워너원)  15
# 방탄소년단            13
# EXO              12
# 비투비               5
# 폴킴                3

# %%
bar_df['score'] = 5
bar_df.plot(kind = 'bar', legend=False, figsize=(15,5),rot=0)

# %%
bar_df.columns= ['곡수', 'score']
bar_df.columns
# Out:
# Index(['곡수', 'score'], dtype='object')

# %%
bar_df['곡수']
# Out:
# 가수
# Wanna One (워너원)    15
# 방탄소년단              13
# EXO                12
# 비투비                 5
# 폴킴                  3
# 멜로망스                2
# TWICE (트와이스)        2
# iKON                2
# 아이유                 2
# 양다일                 2
# Name: 곡수, dtype: int64

# %%
bar_df['곡수'].plot(kind = 'bar', legend=False, figsize=(15,5),rot=0)

# %%
barh1_df = pd.read_excel('data/sample-barh-1.xlsx',index_col = '가수')
barh1_df.columns = ['곡수']
print(bar_df.shape)
barh1_df.head()
# Out:
# (10, 2)
#                      곡수
# 가수
# (여자)아이들               1
# 마미손                   1
# 먼데이 키즈 (Monday Kiz)   1
# 바이브                   1
# 벤                     1

# %%
barh1_df['곡수'].iloc[-10:].plot(kind = 'barh')

# %%
barh2_df = pd.read_excel('data/sample-barh-2.xlsx',index_col = '가수')
print(barh2_df.shape)
barh2_df.head()
# Out:
# (10, 2)
#            곡수  log(좋아요 합)
# 가수
# 로이킴         2   12.600062
# BLACKPINK   2   12.685860
# iKON        2   12.760791
# 멜로망스        2   12.790253
# 아이유         2   13.089049

# %%
barh2_df.iloc[-10:].plot(kind = 'barh',legend=False)

# %%
##scatter 타입

# %%
scatter_df = pd.read_excel('data/sample-scatter.xlsx')
print(scatter_df.shape)
scatter_df.head()
# Out:
# (2826, 2)
#             S&P500 - Ratio  KOSPI200 - Ratio
# 2008-01-02      100.000000        100.000000
# 2008-01-03      100.000000         99.732257
# 2008-01-04       97.544846        100.199745
# 2008-01-07       97.859255         98.172546
# 2008-01-08       96.063324         97.892053

# %%
scatter_df.plot(kind='scatter', x = 'S&P500 - Ratio', y='KOSPI200 - Ratio', figsize=(10,10))

# %%
import seaborn as sns

# %%
sns.regplot(data=scatter_df,x = 'S&P500 - Ratio', y='KOSPI200 - Ratio')
